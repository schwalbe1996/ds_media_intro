# %% [markdown]
# [![Colabで開く](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/schwalbe1996/ds_media_intro/blob/main/chap14_ex.ipynb)

# %%
# !wget -nc https://github.com/schwalbe1996/ds_media_intro/raw/main/sudoku.png

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 画像を読み込む
image = cv2.imread('sudoku.png',cv2.IMREAD_GRAYSCALE)

# %%
# Canny法によりエッジを検出 : ***************の部分を埋めてください．
edges = ************************************

# %%
# Hough変換により直線を検出 : ***************の部分を埋めてください．
lines = ************************************

# %%
disp = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)  # 画像をカラーに変換して表示用の画像を作成
for l in lines: # 検出された各線分ごとに繰り返し
    x0, y0, x1, y1 = l[0]
    # 点(x0,y0)と点(x1,y1)とを結ぶ線分を画像に書き込む
    cv2.line(disp, (x0,y0), (x1,y1), color=(255), thickness=2)    
    
plt.imshow(disp, cmap='gray')
plt.show()
